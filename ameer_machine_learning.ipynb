# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import random
import sklearn

# %%
final_df = pd.read_csv('data/final_dataset_inflated.csv')
final_df
# Out:
#                      Name  Year  \
# 0     10 cloverfield lane  2016
# 1               10,000 bc  2008
# 2               12 rounds  2009
# 3               12 strong  2018
# 4        12 years a slave  2013
# ...                   ...   ...
# 3018            zoolander  2001
# 3019          zoolander 2  2016
# 3020                 zoom  2006
# 3021             zootopia  2016
# 3022            aeon flux  2005
#
#                                               Countries  \
# 0                                         united states
# 1     united states of america, south africa, new ze...
# 2                              united states of america
# 3                                         united states
# 4                              united states of america
# ...                                                 ...
# 3018       united states of america, australia, germany
# 3019                                      united states
# 3020                           united states of america
# 3021                                      united states
# 3022                           united states of america
#
#                                                  Genres  Budget(USD)_Inflated  \
# 0                       drama, horror, sci-fi, thriller          6.076746e+06
# 1     thriller, adventure, costume drama, action/adv...          1.441563e+08
# 2     action thrillers, thriller, action, crime fiction          2.726275e+07
# 3                           action, drama, history, war          3.979050e+07
# 4                             biography, drama, history          2.539260e+07
# ...                                                 ...                   ...
# 3018                   parody, comedy of errors, comedy          4.851315e+07
# 3019        action, adventure, comedy, mystery, romance          6.076746e+07
# 3020        science fiction, action, fantasy, adventure          5.014200e+07
# 3021  action, adventure, animation, comedy, crime, f...          1.823024e+08
# 3022  thriller, science fiction, action, adventure, ...          9.055065e+07
#
#       Domestic(USD)_Inflated  Domestic_Percentage  Foreign(USD)_Inflated  \
# 0               8.760602e+07             0.654010           4.634613e+07
# 1               1.301309e+08             0.351333           2.402606e+08
# 2               1.667757e+07             0.708013           6.877890e+06
# 3               5.209113e+07             0.644274           2.876133e+07
# 4               7.195247e+07             0.301875           1.663993e+08
# ...                      ...                  ...                    ...
# 3018            7.826600e+07             0.743197           2.704388e+07
# 3019            3.506124e+07             0.508592           3.387664e+07
# 3020            1.717625e+07             0.958658           7.407176e+05
# 3021            4.147601e+08             0.333340           8.294952e+08
# 3022            3.778932e+07             0.485250           4.008668e+07
#
#       Foreign_Percentage  Worldwide(USD)_Inflated  Runtime(mins) Rating  \
# 0               0.345990             1.339521e+08            103  pg-13
# 1               0.648667             3.703914e+08            109  pg-13
# 2               0.291987             2.355546e+07            108  pg-13
# 3               0.355726             8.085246e+07            130      r
# 4               0.698125             2.383517e+08            134      r
# ...                  ...                      ...            ...    ...
# 3018            0.256803             1.053099e+08             90  pg-13
# 3019            0.491408             6.893788e+07            101  pg-13
# 3020            0.041342             1.791697e+07             93     pg
# 3021            0.666660             1.244255e+09            108     pg
# 3022            0.514750             7.787601e+07             93  pg-13
#
#      Audience_Score Critics_Score  Cumulative_Inflation
# 0               79%           91%              0.215349
# 1               37%           10%              0.372917
# 2               45%           31%              0.363138
# 3               62%           50%              0.136872
# 4               90%           95%              0.269630
# ...             ...           ...                   ...
# 3018            80%           64%              0.732612
# 3019            20%           22%              0.215349
# 3020            34%            5%              0.432628
# 3021            92%           98%              0.215349
# 3022            39%           10%              0.460494
#
# [3023 rows x 15 columns]

# %% [markdown]
# ## Defining classification target

# %%
import pandas as pd

# Assuming final_df is your DataFrame
final_df["Domestic_Higher"] = (final_df["Domestic_Percentage"] > final_df["Foreign_Percentage"]).astype(int)
